# %% [markdown]
# # Web Scrape Gelest

# %% [markdown]
# Let's import the libraries we'll need. Also, hacking the [government pdfs](https://govhack-toolkit.readthedocs.io/technical/scraping/)

# %%
# import libraries
import PyPDF2
from urllib.request import urlopen
import requests
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import re
import itertools
from bs4 import BeautifulSoup
from rdkit import Chem
from rdkit.Chem import Draw
from util import removeJunk, compoundProperties, getSmiles, getFlashPoint

# %%
text = 'Flash point: > 65 °C'

# %%
#helper methods
def getFlashPoint_old(pdfUrl):
    flashp = -1
    response = urlopen(pdfUrl)
    file = open("document.pdf", 'wb')
    file.write(response.read())
    file.close()
    pdf_file = open('document.pdf', 'rb')
        
    read_pdf = PyPDF2.PdfFileReader(pdf_file)
    
    #number_of_pages = read_pdf.getNumPages()
    for p in range(read_pdf.getNumPages()):
        page = read_pdf.getPage(p)
        text = page.extractText()
        
        text = text.replace('\n', ' ').replace('\r', '')
        fp = re.search('Flash point(.+?)C', text)
        #print(fp)
        if fp != None:
            fp = re.search('Flash point(.+?)C', text).group(0)
            flashPoint = re.findall('\d+', fp)
            #print(int(flashPoint[0]))
            flashp = int(flashPoint[0])
            break
    
    pdf_file.close()
    
    print(flashp)    
    return flashp

# %% [markdown]
# I think we should get the box for each [product](https://www.gelest.com/product-lines/silicones/)

# %%
num = 1
frame = pd.DataFrame(columns=("productCode", "casNum", "compound", "smiles", "flashPoint", "img", "sds")) #frame for scraped data

while num <= 7:
    print("-------------------Page"+str(num)+"------------------------------------------")
    url = "https://www.gelest.com/product-lines/intermediates/?pl_page="+str(num)+"&perpage=20"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    products = soup.find("div", {"class": re.compile("^(first border-box col-xs-24)")})
    contents = soup.find_all("div", {"class": "wc-product-meta"})
    imgs = soup.find_all("img", {"class": "img-responsive center-block wp-post-image"})
    
    for img, data in zip(imgs, contents):
        
        productCode = data.find("span", {"class" : "code"}).text
        sds = soup.find("a", {"href": "https://s3.amazonaws.com/gelest/sds/"+productCode+"_GHS+US_English+US.pdf"})
        casNo = data.find("span", {"class" : "cas-number"})
    
        if casNo == None:
            casNo = ''
        else:
            casNo = casNo.text
        
        compound = data.find("p", {"class" : "title"}).text.strip('\n\t')
        #compound = removeJunk(compound)
        #smilesUrl = "https://opsin.ch.cam.ac.uk/opsin/"+compound+".smi"
        #print(smilesUrl)
        requestSmiles = " " #requests.get(smilesUrl)
    
        if 1 != 1:#requestSmiles.status_code == 400 or requestSmiles.status_code == 404:
            print("no smiles")
        else:
            try:
                if sds != None: #if sds['href'] != None:
                    #print(sds['href'])
                    if sds == None:
                        flashPoint = -1
                    else:
                        flashPoint = getFlashPoint(sds['href'])
                    frame = frame.append({'productCode' : productCode,
                             'casNum' : casNo,
                             'compound' : compound,
                              'smiles' : "", #requestSmiles.text,
                              'flashPoint' : flashPoint,
                             'img' : img['src'],
                             'sds' : sds['href']}, ignore_index=True)
            except:
                print('could not scrap pdf')
                #print(compound, requestSmiles.text, flashPoint)
                #print(sds["href"])

    num+= 1

# %%
frame = frame[frame.flashPoint != -1]
print(frame.shape[0])
frame.to_csv('intermediates_all.csv', encoding='utf-8',index=False)
#sdsUrl = "https://s3.amazonaws.com/gelest/sds/SIA0482.0_GHS+US_English+US.pdf"
#fp = getFlashPoint(sdsUrl)
#print(fp)

# %%
intermediates = pd.read_csv('intermediates_all.csv')
metalOrganics = pd.read_csv('metal-organics_all.csv')
tinCompounds = pd.read_csv('tin-compounds_all.csv')
silanes = pd.read_csv('silanes_all.csv')
germaniumCompounds = pd.read_csv('germanium-compounds_all.csv')
silicones = pd.read_csv('silicones_all.csv')

#compounds = silanes.append([intermediates,
#                            tinCompounds,
##                            germaniumCompounds,
#                            silicones,
#                            metalOrganics])

# %%
#find smiles strings
#silanes['smiles'] = silanes['compound'].apply(getSmiles)
#silanes.to_csv("silanes_all.csv",encoding='utf-8',index=False)

# %%
#silanes
#silanes['Product form'] = silanes['sds'].apply(compoundProperties)
silanes
# Out:
#     productCode                   casNum  \
# 0     SIA0006.0               57757-66-1
# 1     SIA0010.0               18306-45-1
# 2     SIA0015.0               18163-34-3
# 3     SIA0020.0               18204-80-3
# 4     SIA0025.0               22538-45-0
# 6     SIA0035.0             1356113-09-1
# 7     SIA0038.0               14697-86-0
# 8     SIA0050.0                5630-83-1
# 9     SIA0060.0                2917-65-9
# 10    SIA0070.0  627882-90-0/282534-42-3
# 13    SIA0088.0               18044-09-2
# 14    SIA0090.0                5290-24-4
# 15    SIA0100.0               59004-18-1
# 16    SIA0110.0                2754-27-0
# 17    SIA0115.0              959053-85-1
# 21    SIA0130.0               13411-48-8
# 24    SIA0160.0               18269-99-3
# 26    SIA0182.0               21134-38-3
# 28    SIA0186.0               67186-35-0
# 31    SIA0196.0               71550-63-5
# 38    SIA0315.0              157859-20-6
# 39    SIA0320.0               13688-55-6
# 40    SIA0325.0               37843-11-1
# 44    SIA0433.0              447440-43-9
# 46    SIA0441.0              166970-54-3
# 47    SIA0445.0                3937-28-8
# 48    SIA0447.0               18147-35-8
# 50    SIA0461.0              106948-24-7
# 52    SIA0469.0               68469-60-3
# 54    SIA0476.0               85807-85-8
# ..          ...                      ...
# 61    SIA0520.0                 107-37-9
# 62    SIA0525.0                2550-04-1
# 63    SIA0535.0               24400-84-8
# 64    SIA0540.0                2551-83-9
# 65    SIA0555.0                 762-72-1
# 66    SIA0575.0               18752-21-1
# 67    SIA0585.0                7087-21-0
# 69   SIA0587.05              156849-43-3
# 70   SIA0587.07              157923-74-5
# 75    SIA0588.8               70240-34-5
# 82    SIA0592.0               18246-33-8
# 85    SIA0595.0              121772-92-7
# 86    SIA0596.0               18166-02-4
# 90    SIA0599.2    33976-43-1/70411-42-6
# 92    SIA0602.0              117559-36-1
# 93    SIA0603.0               18306-79-1
# 94    SIA0603.6               31024-26-7
# 95    SIA0604.5               42292-18-2
# 96    SIA0605.0                3179-76-8
# 97    SIA0607.0               23029-21-2
# 99    SIA0610.0                 919-30-2
# 103   SIA0611.0               13822-56-5
# 105   SIA0612.0               18187-14-9
# 108   SIA0705.0               16919-19-0
# 109   SIA0710.0                3768-55-6
# 116   SIA0777.0               83315-69-9
# 122   SIB0959.0               76241-02-6
# 123   SIB0960.0               53215-95-5
# 124   SIB0962.0                1833-31-4
# 125   SIB0964.0                1631-70-5
#
#                                               compound  \
# 0                  (3-ACETAMIDOPROPYL)TRIMETHOXYSILANE
# 1                     ACETOXYETHYLDIMETHYLCHLOROSILANE
# 2                     ACETOXYETHYLMETHYLDICHLOROSILANE
# 3                          ACETOXYETHYLTRICHLOROSILANE
# 4                          ACETOXYETHYLTRIETHOXYSILANE
# 6                ACETOXYETHYLTRIS(DIMETHYLAMINO)SILANE
# 7                 ACETOXYHEPTAMETHYLCYCLOTETRASILOXANE
# 8                         ACETOXYMETHYLTRIETHOXYSILANE
# 9                         ACETOXYMETHYLTRIMETHYLSILANE
# 10                   4-ACETOXYPHENETHYLTRICHLOROSILANE
# 13           3-(3-ACETOXYPROPYL)HEPTAMETHYLTRISILOXANE
# 14                 3-ACETOXYPROPYLMETHYLDICHLOROSILANE
# 15                     3-ACETOXYPROPYLTRIMETHOXYSILANE
# 16                              ACETOXYTRIMETHYLSILANE
# 17                    11-ACETOXYUNDECYLTRIETHOXYSILANE
# 21                               ACETYLTRIMETHYLSILANE
# 24                   (2-ACRYLOXYETHOXY)TRIMETHYLSILANE
# 26                      ACRYLOXYMETHYLTRIMETHOXYSILANE
# 28                       ACRYLOXYMETHYLTRIMETHYLSILANE
# 31              (3-ACRYLOXYPROPYL)METHYLDICHLOROSILANE
# 38                          ACRYLOXYTRIISOPROPYLSILANE
# 39                             ACRYLOXYTRIMETHYLSILANE
# 40                       ADAMANTYLETHYLTRICHLOROSILANE
# 44   (S,S)-2-ALLYL-2-CHLORO-3,4-DIMETHYL-5-PHENYL-[...
# 46                 ALLYL(3-CHLOROPROPYL)DICHLOROSILANE
# 47                                 ALLYLDICHLOROSILANE
# 48                                ALLYLDIMETHOXYSILANE
# 50               ALLYLDIMETHYL(DIISOPROPYLAMINO)SILANE
# 52                ALLYL(4-METHOXYPHENYL)DIMETHYLSILANE
# 54                      ALLYLOXY-t-BUTYLDIMETHYLSILANE
# ..                                                 ...
# 61                                ALLYLTRICHLOROSILANE
# 62                                ALLYLTRIETHOXYSILANE
# 63                             ALLYLTRIISOPROPYLSILANE
# 64                               ALLYLTRIMETHOXYSILANE
# 65                                ALLYLTRIMETHYLSILANE
# 66                                ALLYLTRIPHENYLSILANE
# 67                    ALLYLTRIS(TRIMETHYLSILOXY)SILANE
# 69      4-AMINO-3,3-DIMETHYLBUTYLMETHYLDIMETHOXYSILANE
# 70           4-AMINO-3,3-DIMETHYLBUTYLTRIMETHOXYSILANE
# 75   N-(2-AMINOETHYL)-3-AMINOPROPYLMETHYLDIETHOXYSI...
# 82   N-(2-AMINOETHYL)-2,2,4-TRIMETHYL-1-AZA-2-SILAC...
# 85    N-(2-AMINOETHYL)-11-AMINOUNDECYLTRIMETHOXYSILANE
# 86                          AMINOMETHYLTRIMETHYLSILANE
# 90                         AMINOPHENYLTRIMETHOXYSILANE
# 92                3-AMINOPROPYLDIISOPROPYLETHOXYSILANE
# 93                   3-AMINOPROPYLDIMETHYLETHOXYSILANE
# 94                  3-AMINOPROPYLDIMETHYLMETHOXYSILANE
# 95       3-AMINOPROPYLMETHYLBIS(TRIMETHYLSILOXY)SILANE
# 96                   3-AMINOPROPYLMETHYLDIETHOXYSILANE
# 97                  3-AMINOPROPYLPENTAMETHYLDISILOXANE
# 99                        3-AMINOPROPYLTRIETHOXYSILANE
# 103                      3-AMINOPROPYLTRIMETHOXYSILANE
# 105                       3-AMINOPROPYLTRIMETHYLSILANE
# 108                        AMMONIUM HEXAFLUOROSILICATE
# 109                             ANILINOTRIMETHYLSILANE
# 116                       3-AZIDOPROPYLTRIETHOXYSILANE
# 122                   BENZOYLOXYPROPYLTRIMETHOXYSILANE
# 123                 N-BENZYLAMINOMETHYLTRIMETHYLSILANE
# 124                         BENZYLDIMETHYLCHLOROSILANE
# 125                               BENZYLDIMETHYLSILANE
#
#                                                 smiles  flashPoint  \
# 0                           C(C)(=O)NCCC[Si](OC)(OC)OC          65
# 1                              C(C)(=O)OCC[Si](Cl)(C)C          63
# 2                             C(C)(=O)OCC[Si](Cl)(Cl)C          65
# 3                            C(C)(=O)OCC[Si](Cl)(Cl)Cl          82
# 4                         C(C)(=O)OCC[Si](OCC)(OCC)OCC          99
# 6                   C(C)(=O)OCC[Si](N(C)C)(N(C)C)N(C)C          40
# 7    C(C)(=O)O[Si]1(O[Si](O[Si](O[Si](O1)(C)C)(C)C)...          65
# 8                          C(C)(=O)OC[Si](OCC)(OCC)OCC          60
# 9                                C(C)(=O)OC[Si](C)(C)C          20
# 10              C(C)(=O)OC1=CC=C(CC[Si](Cl)(Cl)Cl)C=C1         110
# 13       C(C)(=O)OCCC[Si](O[Si](C)(C)C)(O[Si](C)(C)C)C          65
# 14                           C(C)(=O)OCCC[Si](Cl)(Cl)C          85
# 15                          C(C)(=O)OCCC[Si](OC)(OC)OC          93
# 16                                C(C)(=O)O[Si](C)(C)C           4
# 17               C(C)(=O)OCCCCCCCCCCC[Si](OCC)(OCC)OCC         150
# 21                                 C(C)(=O)[Si](C)(C)C           8
# 24                           C(C=C)(=O)OCCO[Si](C)(C)C          65
# 26                          C(C=C)(=O)OC[Si](OC)(OC)OC          62
# 28                             C(C=C)(=O)OC[Si](C)(C)C          20
# 31                         C(C=C)(=O)OCCC[Si](Cl)(Cl)C         100
# 38                  C(C=C)(=O)O[Si](C(C)C)(C(C)C)C(C)C          65
# 39                              C(C=C)(=O)O[Si](C)(C)C          26
# 40              C12(CC3CC(CC(C1)C3)C2)CC[Si](Cl)(Cl)Cl         155
# 44         C(C=C)[Si@]1(OC([C@@H](N1C)C)C1=CC=CC=C1)Cl          65
# 46                             C(C=C)[Si](Cl)(Cl)CCCCl          76
# 47                                   C(C=C)[SiH](Cl)Cl           4
# 48                                   C(C=C)[SiH](OC)OC          38
# 50                       C(C=C)[Si](N(C(C)C)C(C)C)(C)C          62
# 52                     C(C=C)[Si](C)(C)C1=CC=C(C=C1)OC         102
# 54                           C(C=C)O[Si](C)(C)C(C)(C)C          32
# ..                                                 ...         ...
# 61                                C(C=C)[Si](Cl)(Cl)Cl          31
# 62                             C(C=C)[Si](OCC)(OCC)OCC          47
# 63                       C(C=C)[Si](C(C)C)(C(C)C)C(C)C          76
# 64                                C(C=C)[Si](OC)(OC)OC          46
# 65                                   C(C=C)[Si](C)(C)C           7
# 66     C(C=C)[Si](C1=CC=CC=C1)(C1=CC=CC=C1)C1=CC=CC=C1         200
# 67   C(C=C)[Si](O[Si](C)(C)C)(O[Si](C)(C)C)O[Si](C)...          67
# 69                            NCC(CC[Si](OC)(OC)C)(C)C         100
# 70                           NCC(CC[Si](OC)(OC)OC)(C)C          97
# 75                              NCCNCCC[Si](OCC)(OCC)C         110
# 82                              NCCN1[Si](CC(C1)C)(C)C          65
# 85                       NCCNCCCCCCCCCCC[Si](OC)(OC)OC         150
# 86                                       NC[Si](C)(C)C           9
# 90                          NCO[Si](OC)(OC)C1=CC=CC=C1         180
# 92                           NCCC[Si](OCC)(C(C)C)C(C)C         100
# 93                                   NCCC[Si](OCC)(C)C          73
# 94                                    NCCC[Si](OC)(C)C          20
# 95               NCCC[Si](O[Si](C)(C)C)(O[Si](C)(C)C)C         110
# 96                                 NCCC[Si](OCC)(OCC)C          85
# 97                          NCCC[Si](O[Si](C)(C)C)(C)C          65
# 99                               NCCC[Si](OCC)(OCC)OCC         104
# 103                                 NCCC[Si](OC)(OC)OC          83
# 105                                    NCCC[Si](C)(C)C          59
# 108                 F[Si-2](F)(F)(F)(F)F.[NH4+].[NH4+]          20
# 109                          N(C1=CC=CC=C1)[Si](C)(C)C          65
# 116                  N(=[N+]=[N-])CCC[Si](OCC)(OCC)OCC         110
# 122               C(C1=CC=CC=C1)(=O)OCCC[Si](OC)(OC)OC         110
# 123                        C(C1=CC=CC=C1)NC[Si](C)(C)C         116
# 124                         C(C1=CC=CC=C1)[Si](Cl)(C)C          73
# 125                            C(C1=CC=CC=C1)[SiH](C)C          65
#
#                                                    img  \
# 0    https://www.gelest.com:443/wp-content/uploads/...
# 1    https://www.gelest.com:443/wp-content/uploads/...
# 2    https://www.gelest.com:443/wp-content/uploads/...
# 3    https://www.gelest.com:443/wp-content/uploads/...
# 4    https://www.gelest.com:443/wp-content/uploads/...
# 6    https://www.gelest.com:443/wp-content/uploads/...
# 7    https://www.gelest.com:443/wp-content/uploads/...
# 8    https://www.gelest.com:443/wp-content/uploads/...
# 9    https://www.gelest.com:443/wp-content/uploads/...
# 10   https://www.gelest.com:443/wp-content/uploads/...
# 13   https://www.gelest.com:443/wp-content/uploads/...
# 14   https://www.gelest.com:443/wp-content/uploads/...
# 15   https://www.gelest.com:443/wp-content/uploads/...
# 16   https://www.gelest.com:443/wp-content/uploads/...
# 17   https://www.gelest.com:443/wp-content/uploads/...
# 21   https://www.gelest.com:443/wp-content/uploads/...
# 24   https://www.gelest.com:443/wp-content/uploads/...
# 26   https://www.gelest.com:443/wp-content/uploads/...
# 28   https://www.gelest.com:443/wp-content/uploads/...
# 31   https://www.gelest.com:443/wp-content/uploads/...
# 38   https://www.gelest.com:443/wp-content/uploads/...
# 39   https://www.gelest.com:443/wp-content/uploads/...
# 40   https://www.gelest.com:443/wp-content/uploads/...
# 44   https://www.gelest.com:443/wp-content/uploads/...
# 46   https://www.gelest.com:443/wp-content/uploads/...
# 47   https://www.gelest.com:443/wp-content/uploads/...
# 48   https://www.gelest.com:443/wp-content/uploads/...
# 50   https://www.gelest.com:443/wp-content/uploads/...
# 52   https://www.gelest.com:443/wp-content/uploads/...
# 54   https://www.gelest.com:443/wp-content/uploads/...
# ..                                                 ...
# 61   https://www.gelest.com:443/wp-content/uploads/...
# 62   https://www.gelest.com:443/wp-content/uploads/...
# 63   https://www.gelest.com:443/wp-content/uploads/...
# 64   https://www.gelest.com:443/wp-content/uploads/...
# 65   https://www.gelest.com:443/wp-content/uploads/...
# 66   https://www.gelest.com:443/wp-content/uploads/...
# 67   https://www.gelest.com:443/wp-content/uploads/...
# 69   https://www.gelest.com:443/wp-content/uploads/...
# 70   https://www.gelest.com:443/wp-content/uploads/...
# 75   https://www.gelest.com:443/wp-content/uploads/...
# 82   https://www.gelest.com:443/wp-content/uploads/...
# 85   https://www.gelest.com:443/wp-content/uploads/...
# 86   https://www.gelest.com:443/wp-content/uploads/...
# 90   https://www.gelest.com:443/wp-content/uploads/...
# 92   https://www.gelest.com:443/wp-content/uploads/...
# 93   https://www.gelest.com:443/wp-content/uploads/...
# 94   https://www.gelest.com:443/wp-content/uploads/...
# 95   https://www.gelest.com:443/wp-content/uploads/...
# 96   https://www.gelest.com:443/wp-content/uploads/...
# 97   https://www.gelest.com:443/wp-content/uploads/...
# 99   https://www.gelest.com:443/wp-content/uploads/...
# 103  https://www.gelest.com:443/wp-content/uploads/...
# 105  https://www.gelest.com:443/wp-content/uploads/...
# 108  https://www.gelest.com:443/wp-content/uploads/...
# 109  https://www.gelest.com:443/wp-content/uploads/...
# 116  https://www.gelest.com:443/wp-content/uploads/...
# 122  https://www.gelest.com:443/wp-content/uploads/...
# 123  https://www.gelest.com:443/wp-content/uploads/...
# 124  https://www.gelest.com:443/wp-content/uploads/...
# 125  https://www.gelest.com:443/wp-content/uploads/...
#
#                                                    sds Product form
# 0    https://s3.amazonaws.com/gelest/sds/SIA0006.0_...    Substance
# 1    https://s3.amazonaws.com/gelest/sds/SIA0010.0_...    Substance
# 2    https://s3.amazonaws.com/gelest/sds/SIA0015.0_...    Substance
# 3    https://s3.amazonaws.com/gelest/sds/SIA0020.0_...    Substance
# 4    https://s3.amazonaws.com/gelest/sds/SIA0025.0_...    Substance
# 6    https://s3.amazonaws.com/gelest/sds/SIA0035.0_...    Substance
# 7    https://s3.amazonaws.com/gelest/sds/SIA0038.0_...    Substance
# 8    https://s3.amazonaws.com/gelest/sds/SIA0050.0_...    Substance
# 9    https://s3.amazonaws.com/gelest/sds/SIA0060.0_...    Substance
# 10   https://s3.amazonaws.com/gelest/sds/SIA0070.0_...    Substance
# 13   https://s3.amazonaws.com/gelest/sds/SIA0088.0_...    Substance
# 14   https://s3.amazonaws.com/gelest/sds/SIA0090.0_...    Substance
# 15   https://s3.amazonaws.com/gelest/sds/SIA0100.0_...    Substance
# 16   https://s3.amazonaws.com/gelest/sds/SIA0110.0_...    Substance
# 17   https://s3.amazonaws.com/gelest/sds/SIA0115.0_...    Substance
# 21   https://s3.amazonaws.com/gelest/sds/SIA0130.0_...    Substance
# 24   https://s3.amazonaws.com/gelest/sds/SIA0160.0_...    Substance
# 26   https://s3.amazonaws.com/gelest/sds/SIA0182.0_...    Substance
# 28   https://s3.amazonaws.com/gelest/sds/SIA0186.0_...    Substance
# 31   https://s3.amazonaws.com/gelest/sds/SIA0196.0_...      Mixture
# 38   https://s3.amazonaws.com/gelest/sds/SIA0315.0_...    Substance
# 39   https://s3.amazonaws.com/gelest/sds/SIA0320.0_...    Substance
# 40   https://s3.amazonaws.com/gelest/sds/SIA0325.0_...    Substance
# 44   https://s3.amazonaws.com/gelest/sds/SIA0433.0_...    Substance
# 46   https://s3.amazonaws.com/gelest/sds/SIA0441.0_...    Substance
# 47   https://s3.amazonaws.com/gelest/sds/SIA0445.0_...    Substance
# 48   https://s3.amazonaws.com/gelest/sds/SIA0447.0_...    Substance
# 50   https://s3.amazonaws.com/gelest/sds/SIA0461.0_...    Substance
# 52   https://s3.amazonaws.com/gelest/sds/SIA0469.0_...    Substance
# 54   https://s3.amazonaws.com/gelest/sds/SIA0476.0_...    Substance
# ..                                                 ...          ...
# 61   https://s3.amazonaws.com/gelest/sds/SIA0520.0_...    Substance
# 62   https://s3.amazonaws.com/gelest/sds/SIA0525.0_...    Substance
# 63   https://s3.amazonaws.com/gelest/sds/SIA0535.0_...    Substance
# 64   https://s3.amazonaws.com/gelest/sds/SIA0540.0_...    Substance
# 65   https://s3.amazonaws.com/gelest/sds/SIA0555.0_...    Substance
# 66   https://s3.amazonaws.com/gelest/sds/SIA0575.0_...    Substance
# 67   https://s3.amazonaws.com/gelest/sds/SIA0585.0_...    Substance
# 69   https://s3.amazonaws.com/gelest/sds/SIA0587.05...    Substance
# 70   https://s3.amazonaws.com/gelest/sds/SIA0587.07...    Substance
# 75   https://s3.amazonaws.com/gelest/sds/SIA0588.8_...    Substance
# 82   https://s3.amazonaws.com/gelest/sds/SIA0592.0_...    Substance
# 85   https://s3.amazonaws.com/gelest/sds/SIA0595.0_...    Substance
# 86   https://s3.amazonaws.com/gelest/sds/SIA0596.0_...    Substance
# 90   https://s3.amazonaws.com/gelest/sds/SIA0599.2_...    Substance
# 92   https://s3.amazonaws.com/gelest/sds/SIA0602.0_...    Substance
# 93   https://s3.amazonaws.com/gelest/sds/SIA0603.0_...    Substance
# 94   https://s3.amazonaws.com/gelest/sds/SIA0603.6_...    Substance
# 95   https://s3.amazonaws.com/gelest/sds/SIA0604.5_...    Substance
# 96   https://s3.amazonaws.com/gelest/sds/SIA0605.0_...    Substance
# 97   https://s3.amazonaws.com/gelest/sds/SIA0607.0_...    Substance
# 99   https://s3.amazonaws.com/gelest/sds/SIA0610.0_...    Substance
# 103  https://s3.amazonaws.com/gelest/sds/SIA0611.0_...    Substance
# 105  https://s3.amazonaws.com/gelest/sds/SIA0612.0_...    Substance
# 108  https://s3.amazonaws.com/gelest/sds/SIA0705.0_...    Substance
# 109  https://s3.amazonaws.com/gelest/sds/SIA0710.0_...    Substance
# 116  https://s3.amazonaws.com/gelest/sds/SIA0777.0_...    Substance
# 122  https://s3.amazonaws.com/gelest/sds/SIB0959.0_...    Substance
# 123  https://s3.amazonaws.com/gelest/sds/SIB0960.0_...    Substance
# 124  https://s3.amazonaws.com/gelest/sds/SIB0962.0_...    Substance
# 125  https://s3.amazonaws.com/gelest/sds/SIB0964.0_...    Substance
#
# [63 rows x 8 columns]

# %%
silanes.iloc[0]
silanes = silanes[pd.notnull(silanes['smiles'])]
silanes = silanes.loc[silanes['Product form'] == 'Substance']
silanes['smiles'].isnull().sum().sum()
silanes.to_csv("gelest_silanes_substance.csv",encoding='utf-8',index=False)
#metalOrganics['smiles'] = metalOrganics['compound'].apply(getSmiles)
#tinCompounds['smiles'] = tinCompounds['compound'].apply(getSmiles)
#germaniumCompounds['smiles'] = germaniumCompounds['compound'].apply(getSmiles)

# %%
#metal organics
metalOrganics['smiles'] = metalOrganics['compound'].apply(getSmiles)
metalOrganics = metalOrganics[pd.notnull(metalOrganics['smiles'])]
print(metalOrganics['smiles'].isnull().sum().sum())
metalOrganics = metalOrganics[pd.notnull(metalOrganics['smiles'])]
metalOrganics['Product form'] = metalOrganics['sds'].apply(compoundProperties)
print(metalOrganics['smiles'].isnull().sum().sum())
# Out:
# 0
# 0

# %%
metalOrganics = metalOrganics.loc[metalOrganics['Product form'] == 'Substance']
metalOrganics.to_csv("gelest_metal-organics_substance.csv",encoding='utf-8',index=False)

# %%
# tin compounds
tinCompounds['smiles'] = tinCompounds['compound'].apply(getSmiles)
tinCompounds = tinCompounds[pd.notnull(tinCompounds['smiles'])]
print(tinCompounds['smiles'].isnull().sum().sum())
tinCompounds = tinCompounds[pd.notnull(tinCompounds['smiles'])]
tinCompounds['Product form'] = tinCompounds['sds'].apply(compoundProperties)
print(tinCompounds['smiles'].isnull().sum().sum())

tinCompounds = tinCompounds.loc[tinCompounds['Product form'] == 'Substance']
tinCompounds.to_csv("gelest_tin-compounds_substance.csv",encoding='utf-8',index=False)
# Out:
# 0
# 0

# %%
# germanium compounds
germaniumCompounds['smiles'] = germaniumCompounds['compound'].apply(getSmiles)
germaniumCompounds = germaniumCompounds[pd.notnull(germaniumCompounds['smiles'])]
print(germaniumCompounds['smiles'].isnull().sum().sum())
germaniumCompounds = germaniumCompounds[pd.notnull(germaniumCompounds['smiles'])]
germaniumCompounds['Product form'] = germaniumCompounds['sds'].apply(compoundProperties)
print(germaniumCompounds['smiles'].isnull().sum().sum())

germaniumCompounds = germaniumCompounds.loc[germaniumCompounds['Product form'] == 'Substance']
germaniumCompounds.to_csv("gelest_germanium-compounds_substance.csv",encoding='utf-8',index=False)
# Out:
# 0
# 0

# %% [markdown]
# # Using Opsin web services to request the smiles from IUPAC name

# %%
url = "https://opsin.ch.cam.ac.uk/opsin/ACETOXYETHYLTRIETHOXYSILANE.smi"
r = requests.get(url)
r.text

# %%
m = Chem.MolFromSmiles(r.text)
Draw.MolToImage(m)

m1 = Chem.MolFromSmiles('C(#N)CCC[Si](O[*:2])(C)[*:1]')
Draw.MolToImage(m1)

# %% [markdown]
# # Extract identifiers

# %%
response = urlopen('https://s3.amazonaws.com/gelest/sds/SIA0006.0_GHS+US_English+US.pdf')
file = open("document.pdf", 'wb')
file.write(response.read())
file.close()
pdf_file = open('document.pdf', 'rb')
read_pdf = PyPDF2.PdfFileReader(pdf_file)

# %%
page = read_pdf.getPage(0)
text = page.extractText()
text = text.replace('\n', ' ').replace('\r', '')
text

# %%
fp = re.search('Product form(.+?) P', text)
string = fp.group(0)
strArray = string.split()
print(strArray[3])
fp = re.search('Physical state(.+?) F', text)
string = fp.group(0)
strArray = string.split()
print(strArray[3])
fp = re.search('Chemical family(.+?) 1', text)
string = fp.group(0)
strArray = string.split()
print(strArray[3])
